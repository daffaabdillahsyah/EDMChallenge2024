# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
url = 'https://quotes.toscrape.com/'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}

# %%
df = []
req = requests.get(url, headers=headers)
soup = BeautifulSoup(req.text, 'html.parser')
quotes = soup.findAll('div', 'quote')

# %%
for i in review:
  quote = i.find('span', 'text').text
  author = i.find('small', 'author').text
  tags = i.find('div', 'tags').text
  df.append([quote, author, tags])

# %%
column = ['quotes', 'author', 'tags']
file = csv.writer(open('/content/hasil/hasil-scraping.csv', 'w', newline='', encoding='utf-8'))

# %%
file.writerow(column)
for x in df:
  file.writerow(x)

# %%
df = pd.read_csv('/content/hasil/hasil-scraping.csv')
df.head()
# Out:
#                                               quotes           author  \
# 0  “The world as we have created it is a process ...  Albert Einstein
# 1  “It is our choices, Harry, that show what we t...     J.K. Rowling
# 2  “There are only two ways to live your life. On...  Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...      Jane Austen
# 4  “Imperfection is beauty, madness is genius and...   Marilyn Monroe
#
#                                                 tags
# 0  \n            Tags:\n            \nchange\ndee...
# 1  \n            Tags:\n            \nabilities\n...
# 2  \n            Tags:\n            \ninspiration...
# 3  \n            Tags:\n            \naliteracy\n...
# 4  \n            Tags:\n            \nbe-yourself...
